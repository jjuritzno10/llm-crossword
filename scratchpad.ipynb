# %% [markdown]
# # Scratchpad
#
# A notebook for quickly iterating ideas

# %%
import os
from dotenv import load_dotenv
from openai import AzureOpenAI
from src.crossword.utils import load_puzzle

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# Load the puzzle
puzzle = load_puzzle("data/easy.json")

# %%
print('--- Clues ---')
clue = puzzle.clues[0]
print(clue)
# Out:
# --- Clues ---
# number=1 text='Feline friend' direction=<Direction.ACROSS: 'across'> length=3 row=0 col=0 answer='CAT' answered=False

# %%
print('--- Set a guess ---')
puzzle.set_clue_chars(puzzle.clues[0], ["a", "b", "c"])
print(puzzle)
# Out:
# --- Set a guess ---
# ┌───────────────┐
# │ A  B  C  ░  ░ │
# │    ░     ░  ░ │
# │    ░     ░  ░ │
# │ ░  ░     ░  ░ │
# │ ░  ░  ░  ░  ░ │
# └───────────────┘

# %%
print('--- Undo ---')
puzzle.undo()
print(puzzle)
# Out:
# --- Undo ---
# ┌───────────────┐
# │          ░  ░ │
# │    ░     ░  ░ │
# │    ░     ░  ░ │
# │ ░  ░     ░  ░ │
# │ ░  ░  ░  ░  ░ │
# └───────────────┘

# %%
print('--- Set a guess for clue 1 ---')
puzzle.set_clue_chars(puzzle.clues[0], ["c", "a", "t"])

print('--- Set a guess for clue 2 ---')
puzzle.set_clue_chars(puzzle.clues[1], ["c", "o", "w"])

print('--- Completed all? ---')
print(puzzle.validate_all())
print(puzzle)
# Out:
# --- Set a guess for clue 1 ---
# --- Set a guess for clue 2 ---
# --- Completed all? ---
# False
# ┌───────────────┐
# │ C  A  T  ░  ░ │
# │ O  ░     ░  ░ │
# │ W  ░     ░  ░ │
# │ ░  ░     ░  ░ │
# │ ░  ░  ░  ░  ░ │
# └───────────────┘

# %%
print('--- Set a guess for clue 3 ---')
puzzle.set_clue_chars(puzzle.clues[2], ["t", "e", "a","r"])

print('--- Completed all? ---')
print(puzzle.validate_all())
print(puzzle)
# Out:
# --- Set a guess for clue 3 ---
# --- Completed all? ---
# True
# ┌───────────────┐
# │ C  A  T  ░  ░ │
# │ O  ░  E  ░  ░ │
# │ W  ░  A  ░  ░ │
# │ ░  ░  R  ░  ░ │
# │ ░  ░  ░  ░  ░ │
# └───────────────┘

# %%
print('--- Reset ---')
puzzle.reset()
print(puzzle)
# Out:
# --- Reset ---
# ┌───────────────┐
# │          ░  ░ │
# │    ░     ░  ░ │
# │    ░     ░  ░ │
# │ ░  ░     ░  ░ │
# │ ░  ░  ░  ░  ░ │
# └───────────────┘

# %%
print('--- OpenAI Hello World ---')
def openai_hello_world():
    client = AzureOpenAI(
        api_version=os.getenv("OPENAI_API_VERSION"),
        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
        api_key=os.getenv("OPENAI_API_KEY")
    )
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "system", "content": "You are a helpful assistant."}, 
                  {"role": "user", "content": "Hello!"}]
    )
    return response.choices[0].message.content

client = AzureOpenAI(
        api_version=os.getenv("OPENAI_API_VERSION"),
        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
        api_key=os.getenv("OPENAI_API_KEY")
    )

def query(query : str, system_prompt: str = "You are a helpful assistant.") -> str:

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "system", "content": system_prompt}, 
                  {"role": "user", "content": query}]
    )
    return response.choices[0].message.content
    

print(openai_hello_world())
# Out:
# --- OpenAI Hello World ---
# Hi there! How can I assist you today?

# %%
import os
from typing import List, Dict, Optional

import logging

from src.crossword.utils import load_puzzle, CrosswordPuzzle
from src.crossword.types import Clue

logging.basicConfig(level=logging.INFO)


class Solver:
    def __init__(self, puzzle: CrosswordPuzzle):
        """
        Initialize the solver with a CrosswordPuzzle instance.
        
        Args:
            puzzle (CrosswordPuzzle): The crossword puzzle to solve.
        """
        self.puzzle = puzzle
        self.client = AzureOpenAI(
            api_version=os.getenv("OPENAI_API_VERSION"),
            azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
            api_key=os.getenv("OPENAI_API_KEY")
        )

    def make_guess(self, clue: Clue) -> Optional[str]:
        """
        Use the OpenAI API to make a guess for the given clue.
        
        Args:
            clue (Clue): The clue for which to generate a guess.
        
        Returns:
            Optional[str]: The guessed answer, or None if no answer is generated.
        """

        logging.info(f"Making a guess for clue: {clue}")
        prompt = self._generate_prompt(clue)

        response = self.client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are an expert crossword-solving assistant and winner of all major cross-word competitions."},
                {"role": "user", "content": prompt}
            ]
        )

        guess = response.choices[0].message.content.strip().lower()

        logging.info(f"Guess: {guess}")
        
        return guess if len(guess) == clue.length else None

    def solve(self):
        """
        Attempt to solve the entire crossword by making guesses for each clue.
        """
        for clue in self.puzzle.clues:
            logging.info(f"Solving clue: {clue}")
            if not clue.answered:
                guess = self.make_guess(clue)

                if guess:
                    self.puzzle.set_clue_chars(clue, list(guess))

    def validate_solution(self) -> bool:
        """
        Validate the solution of the crossword.
        
        Returns:
            bool: True if all clues are correctly solved, otherwise False.
        """
        validation = self.puzzle.validate_all()

        if validation:
            logging.info("Puzzle solved!")
        
        else:
            logging.info("Puzzle not solved.")

        return validation

    @staticmethod
    def _generate_prompt(clue: Clue) -> str:
        """
        Generate a suitable prompt for the OpenAI API to guess the clue answer.
        
        Args:
            clue (Clue): The clue for which to generate a prompt.
        
        Returns:
            str: The formatted prompt.
        """
        return (
            f"Please solve the following crossword clue:\n\n"
            f"Clue: {clue.text}\n"
            f"Direction: {'Across' if clue.direction == 'across' else 'Down'}\n"
            f"Length: {clue.length}\n"
            #f"Known Letters: {''.join(ch or '_' for ch in clue.cells())}\n\n"
            f"Provide your best guess as a single word in lowercase, "
            f"exactly {clue.length} characters long."
            "You must return ONLY the answer to the clue, not the clue itself and not any other text."
        )

# %%
puzzle = load_puzzle("data/easy.json")

solver = Solver(puzzle)

solver.solve()

solver.validate_solution()
# Out:
# INFO:root:Solving clue: number=1 text='Feline friend' direction=<Direction.ACROSS: 'across'> length=3 row=0 col=0 answer='CAT' answered=False
# INFO:root:Making a guess for clue: number=1 text='Feline friend' direction=<Direction.ACROSS: 'across'> length=3 row=0 col=0 answer='CAT' answered=False
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Guess: cat
# INFO:root:Solving clue: number=1 text='Dairy farm animal' direction=<Direction.DOWN: 'down'> length=3 row=0 col=0 answer='COW' answered=False
# INFO:root:Making a guess for clue: number=1 text='Dairy farm animal' direction=<Direction.DOWN: 'down'> length=3 row=0 col=0 answer='COW' answered=False
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Guess: cow
# INFO:root:Solving clue: number=2 text='A drop of sadness' direction=<Direction.DOWN: 'down'> length=4 row=0 col=2 answer='TEAR' answered=False
# INFO:root:Making a guess for clue: number=2 text='A drop of sadness' direction=<Direction.DOWN: 'down'> length=4 row=0 col=2 answer='TEAR' answered=False
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Guess: tear
# INFO:root:Puzzle solved!
# True

# %%
from typing import List
import logging

def get_ranked_answers(clue: Clue, client, attempt = 0, n_answers = 5) -> List[str]:
    """
    Use the OpenAI API to get three possible answers for a clue ranked in confidence order.
    
    Args:
        clue (Clue): The clue for which to generate answers.
        client: The OpenAI client instance.
    
    Returns:
        List[str]: A list of three ranked answers for the clue.
    """
    prompt = (
        f"Please solve the following crossword clue:\n\n"
        f"Clue: {clue.text}\n"
        f"Direction: {'Across' if clue.direction == 'across' else 'Down'}\n"
        f"Length: {clue.length}\n"
        f"Provide your top {n_answers} answers as a single word for each, "
        f"ranked in order of confidence from highest to lowest, "
        f"separated by commas. Return only the answers."
    )

    logging.info(f"Generating ranked answers for clue: {clue.text}")

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "You are an expert crossword-solving assistant."},
            {"role": "user", "content": prompt}
        ]
    )

    try:
        answers = response.choices[0].message.content.strip().lower().split(",")

    except AttributeError as e:
        logging.error(f"Error generating answers: {e}")
        

    ranked_answers = [answer.strip() for answer in answers]

    # Filter out any answers that are not the correct length.
    ranked_answers = [answer for answer in ranked_answers if len(answer) == clue.length]

    logging.info(f"Ranked answers: {ranked_answers}")

    if (not ranked_answers) and attempt < n_answers:
        logging.info("No valid answers generated. Retrying.")
        return get_ranked_answers(clue, client, attempt + 1)

    return ranked_answers[:n_answers]  # Ensure only the top three are returned.

# %%
from itertools import product
from typing import List
from src.crossword.exceptions import InvalidClueError

class CombinationSolver:
    def __init__(self, puzzle: CrosswordPuzzle, client):
        """
        Initialize the combination solver with a crossword puzzle and OpenAI client.
        
        Args:
            puzzle (CrosswordPuzzle): The crossword puzzle to solve.
            client: The OpenAI client for generating answers.
        """
        self.puzzle = puzzle
        self.client = client
        self.clue_answers = {}

    def generate_clue_answers(self):
        """
        Generate three ranked answers for each clue in the puzzle.
        """
        for clue in self.puzzle.clues:
            if not clue.answered:
                self.clue_answers[clue] = get_ranked_answers(clue, self.client)

    def solve_with_combinations(self):
        """
        Try all combinations of ranked answers for the clues and validate the solution.
        
        Returns:
            bool: True if a valid solution is found, otherwise False.
        """
        self.generate_clue_answers()

        logging.info("Clue answers:")
        for clue, answers in self.clue_answers.items():
            logging.info(f"Clue {clue}: {answers}")

        # Generate all combinations of ranked answers
        clue_combinations = product(
            *[self.clue_answers[clue] for clue in self.puzzle.clues if not clue.answered]
        )

        for combination in clue_combinations:
            logging.info(f"Trying combination: {combination}")
            self.puzzle.reset()

            try:

                # Apply each answer to the corresponding clue
                for clue, answer in zip(self.puzzle.clues, combination):
                    if not clue.answered:
                        self.puzzle.set_clue_chars(clue, list(answer))

            except InvalidClueError as e:
                logging.info(f"Invalid clue encountered: {e}")
                continue

            # Validate the solution
            if self.puzzle.validate_all():
                logging.info("Valid solution found!")
                return True

        logging.info("No valid solution found.")
        return False

# %%
puzzle = load_puzzle("data/medium.json")

solver = CombinationSolver(puzzle, client)

solver.solve_with_combinations()
# Out:
# INFO:root:Generating ranked answers for clue: A long narrative poem
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['epic', 'saga', 'epoe', 'song', 'ball']
# INFO:root:Generating ranked answers for clue: A person who writes books
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['author', 'writer']
# INFO:root:Generating ranked answers for clue: A short story with a moral lesson
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['parable']
# INFO:root:Generating ranked answers for clue: A book's outer casing
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['cover', 'spine', 'guard']
# INFO:root:Generating ranked answers for clue: A narrative tale
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['story', 'novel', 'myths', 'fable']
# INFO:root:Clue answers:
# INFO:root:Clue number=1 text='A long narrative poem' direction=<Direction.ACROSS: 'across'> length=4 row=0 col=0 answer='EPIC' answered=False: ['epic', 'saga', 'epoe', 'song', 'ball']
# INFO:root:Clue number=2 text='A person who writes books' direction=<Direction.ACROSS: 'across'> length=6 row=3 col=1 answer='AUTHOR' answered=False: ['author', 'writer']
# INFO:root:Clue number=1 text='A short story with a moral lesson' direction=<Direction.DOWN: 'down'> length=7 row=0 col=1 answer='PARABLE' answered=False: ['parable']
# INFO:root:Clue number=2 text="A book's outer casing" direction=<Direction.DOWN: 'down'> length=5 row=2 col=5 answer='COVER' answered=False: ['cover', 'spine', 'guard']
# INFO:root:Clue number=3 text='A narrative tale' direction=<Direction.DOWN: 'down'> length=5 row=2 col=3 answer='STORY' answered=False: ['story', 'novel', 'myths', 'fable']
# INFO:root:Trying combination: ('epic', 'author', 'parable', 'cover', 'story')
# INFO:root:Valid solution found!
# True

# %%
puzzle = load_puzzle("data/hard.json")

solver = CombinationSolver(puzzle, client)

solver.solve_with_combinations()
# Out:
# INFO:root:Generating ranked answers for clue: Greek tragedy (7,3)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: []
# INFO:root:No valid answers generated. Retrying.
# INFO:root:Generating ranked answers for clue: Greek tragedy (7,3)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: []
# INFO:root:No valid answers generated. Retrying.
# INFO:root:Generating ranked answers for clue: Greek tragedy (7,3)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: []
# INFO:root:No valid answers generated. Retrying.
# INFO:root:Generating ranked answers for clue: Greek tragedy (7,3)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: []
# INFO:root:No valid answers generated. Retrying.
# INFO:root:Generating ranked answers for clue: Greek tragedy (7,3)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['trojan war']
# INFO:root:Generating ranked answers for clue: A year (3,5)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['one nine', 'one year']
# INFO:root:Generating ranked answers for clue: Elliptical shape (4)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['oval', 'loop', 'orbs', 'arcs', 'obit']
# INFO:root:Generating ranked answers for clue: Feeling of discomfort (4)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['ache', 'pain', 'ills', 'unez', 'edgy']
# INFO:root:Generating ranked answers for clue: Kernel (7)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['nucleus', 'essence']
# INFO:root:Generating ranked answers for clue: Safety equipment for a biker, say (5,6)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['crashhelmet', 'bikerjacket', 'kneeprotect', 'ridingboots']
# INFO:root:Generating ranked answers for clue: Perform tricks (7)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['conjure', 'confuse', 'bewitch']
# INFO:root:Generating ranked answers for clue: Prickly seed case (4)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['burr', 'husk', 'case', 'husk']
# INFO:root:Generating ranked answers for clue: Squad (4)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['team', 'unit', 'gang', 'crew', 'band']
# INFO:root:Generating ranked answers for clue: Impasse (8)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['deadlock', 'gridlock']
# INFO:root:Generating ranked answers for clue: Mess (4,6)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['hodgepodge']
# INFO:root:Generating ranked answers for clue: Greek letter (5)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['delta', 'theta', 'gamma', 'omega']
# INFO:root:Generating ranked answers for clue: Greek money, formerly (7)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['drachma', 'drachms', 'oboliti']
# INFO:root:Generating ranked answers for clue: Small and weak (4)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['puny', 'wimp', 'thin', 'weak', 'weak']
# INFO:root:Generating ranked answers for clue: Academic term (8)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['semester', 'tetrames', 'academic', 'bimonthy']
# INFO:root:Generating ranked answers for clue: Call up (5)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['evoke', 'raise', 'refer', 'rally']
# INFO:root:Generating ranked answers for clue: Surgical knife (6)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['lancet', 'kirpan']
# INFO:root:Generating ranked answers for clue: Parlour game (8)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['charades', 'scrabble', 'monopoly', 'cluegama']
# INFO:root:Generating ranked answers for clue: Bragged (6)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['crowed']
# INFO:root:Generating ranked answers for clue: Schmaltzy (7)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['mawkish', 'sacchar']
# INFO:root:Generating ranked answers for clue: Huge (5)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['great', 'giant', 'large', 'enorm']
# INFO:root:Generating ranked answers for clue: Fast car or fast driver (5)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['racer', 'speed', 'flier']
# INFO:root:Generating ranked answers for clue: Travellers who followed a star (4)
# INFO:httpx:HTTP Request: POST https://i-dot-ai-interview.openai.azure.com//openai/deployments/gpt-4o/chat/completions?api-version=2024-10-01-preview "HTTP/1.1 200 OK"
# INFO:root:Ranked answers: ['magi', 'wise', 'asts']
# INFO:root:Clue answers:
# INFO:root:Clue number=1 text='Greek tragedy (7,3)' direction=<Direction.ACROSS: 'across'> length=10 row=0 col=1 answer='OEDIPUSREX' answered=False: ['trojan war']
# INFO:root:Clue number=2 text='A year (3,5)' direction=<Direction.ACROSS: 'across'> length=8 row=2 col=0 answer='PERANNUM' answered=False: ['one nine', 'one year']
# INFO:root:Clue number=3 text='Elliptical shape (4)' direction=<Direction.ACROSS: 'across'> length=4 row=2 col=9 answer='OVAL' answered=False: ['oval', 'loop', 'orbs', 'arcs', 'obit']
# INFO:root:Clue number=4 text='Feeling of discomfort (4)' direction=<Direction.ACROSS: 'across'> length=4 row=4 col=1 answer='ACHE' answered=False: ['ache', 'pain', 'ills', 'unez', 'edgy']
# INFO:root:Clue number=5 text='Kernel (7)' direction=<Direction.ACROSS: 'across'> length=7 row=4 col=6 answer='ESSENCE' answered=False: ['nucleus', 'essence']
# INFO:root:Clue number=6 text='Safety equipment for a biker, say (5,6)' direction=<Direction.ACROSS: 'across'> length=11 row=6 col=1 answer='CRASHHELMET' answered=False: ['crashhelmet', 'bikerjacket', 'kneeprotect', 'ridingboots']
# INFO:root:Clue number=7 text='Perform tricks (7)' direction=<Direction.ACROSS: 'across'> length=7 row=8 col=0 answer='CONJURE' answered=False: ['conjure', 'confuse', 'bewitch']
# INFO:root:Clue number=8 text='Prickly seed case (4)' direction=<Direction.ACROSS: 'across'> length=4 row=8 col=8 answer='BURR' answered=False: ['burr', 'husk', 'case', 'husk']
# INFO:root:Clue number=9 text='Squad (4)' direction=<Direction.ACROSS: 'across'> length=4 row=10 col=0 answer='TEAM' answered=False: ['team', 'unit', 'gang', 'crew', 'band']
# INFO:root:Clue number=10 text='Impasse (8)' direction=<Direction.ACROSS: 'across'> length=8 row=10 col=5 answer='DEADLOCK' answered=False: ['deadlock', 'gridlock']
# INFO:root:Clue number=11 text='Mess (4,6)' direction=<Direction.ACROSS: 'across'> length=10 row=12 col=2 answer='DOGSDINNER' answered=False: ['hodgepodge']
# INFO:root:Clue number=12 text='Greek letter (5)' direction=<Direction.DOWN: 'down'> length=5 row=0 col=1 answer='OMEGA' answered=False: ['delta', 'theta', 'gamma', 'omega']
# INFO:root:Clue number=13 text='Greek money, formerly (7)' direction=<Direction.DOWN: 'down'> length=7 row=0 col=3 answer='DRACHMA' answered=False: ['drachma', 'drachms', 'oboliti']
# INFO:root:Clue number=14 text='Small and weak (4)' direction=<Direction.DOWN: 'down'> length=4 row=0 col=5 answer='PUNY' answered=False: ['puny', 'wimp', 'thin', 'weak', 'weak']
# INFO:root:Clue number=15 text='Academic term (8)' direction=<Direction.DOWN: 'down'> length=8 row=0 col=7 answer='SEMESTER' answered=False: ['semester', 'tetrames', 'academic', 'bimonthy']
# INFO:root:Clue number=16 text='Call up (5)' direction=<Direction.DOWN: 'down'> length=5 row=0 col=9 answer='EVOKE' answered=False: ['evoke', 'raise', 'refer', 'rally']
# INFO:root:Clue number=17 text='Surgical knife (6)' direction=<Direction.DOWN: 'down'> length=6 row=1 col=11 answer='LANCET' answered=False: ['lancet', 'kirpan']
# INFO:root:Clue number=18 text='Parlour game (8)' direction=<Direction.DOWN: 'down'> length=8 row=5 col=5 answer='CHARADES' answered=False: ['charades', 'scrabble', 'monopoly', 'cluegama']
# INFO:root:Clue number=19 text='Bragged (6)' direction=<Direction.DOWN: 'down'> length=6 row=6 col=1 answer='CROWED' answered=False: ['crowed']
# INFO:root:Clue number=20 text='Schmaltzy (7)' direction=<Direction.DOWN: 'down'> length=7 row=6 col=9 answer='MAUDLIN' answered=False: ['mawkish', 'sacchar']
# INFO:root:Clue number=21 text='Huge (5)' direction=<Direction.DOWN: 'down'> length=5 row=8 col=3 answer='JUMBO' answered=False: ['great', 'giant', 'large', 'enorm']
# INFO:root:Clue number=22 text='Fast car or fast driver (5)' direction=<Direction.DOWN: 'down'> length=5 row=8 col=11 answer='RACER' answered=False: ['racer', 'speed', 'flier']
# INFO:root:Clue number=23 text='Travellers who followed a star (4)' direction=<Direction.DOWN: 'down'> length=4 row=9 col=7 answer='MAGI' answered=False: ['magi', 'wise', 'asts']
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'great', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'great', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'great', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'great', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'great', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'great', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'great', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'great', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'great', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'giant', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'giant', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'giant', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'giant', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'giant', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'giant', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'giant', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'giant', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'giant', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'large', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'large', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'large', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'large', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'large', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'large', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'large', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'large', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'large', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'enorm', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'enorm', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'enorm', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'enorm', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'enorm', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'enorm', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'enorm', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'enorm', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'mawkish', 'enorm', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'great', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'great', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'great', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'great', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'great', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'great', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'great', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'great', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'great', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'giant', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'giant', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'giant', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'giant', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'giant', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'giant', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'giant', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'giant', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'giant', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'large', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'large', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'large', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'large', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'large', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'large', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'large', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'large', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'large', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'enorm', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'enorm', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'enorm', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'enorm', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'enorm', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'enorm', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'enorm', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'enorm', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'charades', 'crowed', 'sacchar', 'enorm', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'great', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'great', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'great', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'great', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'great', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'great', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'great', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'great', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'great', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'giant', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'giant', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'giant', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'giant', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'giant', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'giant', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'giant', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'giant', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'giant', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'large', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'large', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'large', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'large', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'large', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'large', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'large', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'large', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'large', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'evoke', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'flier', 'magi')
# ...
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'mawkish', 'enorm', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'great', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'giant', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'large', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'enorm', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'enorm', 'racer', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'enorm', 'racer', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'enorm', 'speed', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'enorm', 'speed', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'enorm', 'speed', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'enorm', 'flier', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'enorm', 'flier', 'wise')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'scrabble', 'crowed', 'sacchar', 'enorm', 'flier', 'asts')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'monopoly', 'crowed', 'mawkish', 'great', 'racer', 'magi')
# INFO:root:Trying combination: ('trojan war', 'one nine', 'oval', 'ache', 'nucleus', 'crashhelmet', 'conjure', 'burr', 'team', 'deadlock', 'hodgepodge', 'delta', 'drachma', 'puny', 'semester', 'raise', 'lancet', 'monopoly', 'crowed', 'mawkish', 'great', 'racer', 'wise')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 5
#       1 puzzle = load_puzzle("data/hard.json")
#       3 solver = CombinationSolver(puzzle, client)
# ----> 5 solver.solve_with_combinations()
#
# Cell In[34], line 53, in CombinationSolver.solve_with_combinations(self)
#      51     for clue, answer in zip(self.puzzle.clues, combination):
#      52         if not clue.answered:
# ---> 53             self.puzzle.set_clue_chars(clue, list(answer))
#      55 except InvalidClueError as e:
#      56     logging.info(f"Invalid clue encountered: {e}")
#
# File ~/Documents/code/llm-crossword/src/crossword/crossword.py:71, in CrosswordPuzzle.set_clue_chars(self, clue, chars)
#      68 chars = [char.upper() for char in chars]
#      70 # Create new grid based on current state
# ---> 71 new_grid = self.current_grid.model_copy(deep=True)
#      73 for (row, col), char in zip(clue.cells(), chars):
#      74     new_grid.cells[row][col].value = char
#
# File ~/Documents/code/llm-crossword/venv/lib/python3.11/site-packages/pydantic/main.py:337, in BaseModel.model_copy(self, update, deep)
#     324 def model_copy(self, *, update: dict[str, Any] | None = None, deep: bool = False) -> Self:
#     325     """Usage docs: https://docs.pydantic.dev/2.9/concepts/serialization/#model_copy
#     326
#     327     Returns a copy of the model.
#    (...)
#     335         New model instance.
#     336     """
# --> 337     copied = self.__deepcopy__() if deep else self.__copy__()
#     338     if update:
#     339         if self.model_config.get('extra') == 'allow':
#
# File ~/Documents/code/llm-crossword/venv/lib/python3.11/site-packages/pydantic/main.py:805, in BaseModel.__deepcopy__(self, memo)
#     803 cls = type(self)
#     804 m = cls.__new__(cls)
# --> 805 _object_setattr(m, '__dict__', deepcopy(self.__dict__, memo=memo))
#     806 _object_setattr(m, '__pydantic_extra__', deepcopy(self.__pydantic_extra__, memo=memo))
#     807 # This next line doesn't need a deepcopy because __pydantic_fields_set__ is a set[str],
#     808 # and attempting a deepcopy would be marginally slower.
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/Documents/code/llm-crossword/venv/lib/python3.11/site-packages/pydantic/main.py:805, in BaseModel.__deepcopy__(self, memo)
#     803 cls = type(self)
#     804 m = cls.__new__(cls)
# --> 805 _object_setattr(m, '__dict__', deepcopy(self.__dict__, memo=memo))
#     806 _object_setattr(m, '__pydantic_extra__', deepcopy(self.__pydantic_extra__, memo=memo))
#     807 # This next line doesn't need a deepcopy because __pydantic_fields_set__ is a set[str],
#     808 # and attempting a deepcopy would be marginally slower.
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/copy.py:128, in deepcopy(x, memo, _nil)
#     124     d[PyStringMap] = PyStringMap.copy
#     126 del d, t
# --> 128 def deepcopy(x, memo=None, _nil=[]):
#     129     """Deep copy operation on arbitrary Python objects.
#     130
#     131     See the module's __doc__ string for more info.
#     132     """
#     134     if memo is None:
#
# KeyboardInterrupt:
